# %%
import pandas as pd

url = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
covid = pd.read_csv(url)
covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 175981      ZWE    Africa     Zimbabwe  2022-03-29     246042.0      115.0
# 175982      ZWE    Africa     Zimbabwe  2022-03-30     246182.0      140.0
# 175983      ZWE    Africa     Zimbabwe  2022-03-31     246286.0      104.0
# 175984      ZWE    Africa     Zimbabwe  2022-04-01     246414.0      128.0
# 175985      ZWE    Africa     Zimbabwe  2022-04-02     246481.0       67.0
#
# ...

# %%
# 한국 데이터
KOR = covid['iso_code']=="KOR"
covid_kor = covid[KOR]
covid_kor
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 147356      KOR      Asia  South Korea  2020-01-22          1.0        NaN
# 147357      KOR      Asia  South Korea  2020-01-23          1.0        0.0
# 147358      KOR      Asia  South Korea  2020-01-24          2.0        1.0
# 147359      KOR      Asia  South Korea  2020-01-25          2.0        0.0
# 147360      KOR      Asia  South Korea  2020-01-26          3.0        1.0
# ...         ...       ...          ...         ...          ...        ...
# 148153      KOR      Asia  South Korea  2022-03-29   12774956.0   424528.0
# 148154      KOR      Asia  South Korea  2022-03-30   13095631.0   320675.0
# 148155      KOR      Asia  South Korea  2022-03-31   13375818.0   280187.0
# 148156      KOR      Asia  South Korea  2022-04-01   13639915.0   264097.0
# 148157      KOR      Asia  South Korea  2022-04-02   13874216.0   234301.0
#
# ...
